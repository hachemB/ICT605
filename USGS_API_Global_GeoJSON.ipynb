# %% [markdown]
# # Importing Libraries

# %%
# Standard libraries for data manipulation
import pandas as pd
import numpy as np

# Libraries for visualization
import matplotlib.pyplot as plt
import seaborn as sns
import holoviews as hv
from bokeh.io import output_file, show
from holoviews import dim, opts

# Geospatial libraries and tools
from mpl_toolkits.basemap import Basemap
import geopandas as gpd
import shapely.geometry

# Utilities
from io import BytesIO
import requests
import datetime as dt

# Initializing holoviews with bokeh
hv.extension('bokeh')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %% [markdown]
# # Requesting Data

# %%
# Define the query parameters
query = dict(starttime="2013-09-22", endtime="2023-09-22", minmagnitude="5.0", format="geojson", limit="20000")
query_string = '&'.join('{0}={1}'.format(k, v) for k, v in query.items())
query_url = "http://earthquake.usgs.gov/fdsnws/event/1/query?" + query_string

# Get the data
response = requests.get(query_url)
data = response.json()

# Convert the GeoJSON data to a GeoDataFrame
data = gpd.GeoDataFrame.from_features(data['features'])

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## General Understanding of the Data

# %%
# Check the first few rows
data.head()
# Out:
#                                   geometry  mag  \
# 0    POINT Z (141.83280 30.95780 12.73400)  5.7
# 1  POINT Z (167.18980 -14.00390 188.41900)  6.1
# 2  POINT Z (-178.21700 -30.64210 40.10400)  5.6
# 3   POINT Z (144.63760 13.78760 148.41600)  5.0
# 4   POINT Z (-160.37210 54.97110 50.60800)  5.4
#
#                              place           time        updated  tz  \
# 0        Izu Islands, Japan region  1695331332556  1695418035832 NaN
# 1       41 km WSW of Sola, Vanuatu  1695330709950  1695417515235 NaN
# 2    Kermadec Islands, New Zealand  1695309632162  1695396869104 NaN
# 3                             None  1695289702893  1696067911611 NaN
# 4  41 km SSE of Sand Point, Alaska  1695258839537  1696037045583 NaN
#
#                                                  url  \
# 0  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  https://earthquake.usgs.gov/earthquakes/eventp...
# 2  https://earthquake.usgs.gov/earthquakes/eventp...
# ...

# %%
# Keep only the specified columns
desired_columns = ['geometry', 'mag', 'place', 'time', 'type', 'title']
gdf = data[desired_columns]

# Display the first few rows of the updated GeoDataFrame to verify
gdf.head()
# Out:
#                                   geometry  mag  \
# 0    POINT Z (141.83280 30.95780 12.73400)  5.7
# 1  POINT Z (167.18980 -14.00390 188.41900)  6.1
# 2  POINT Z (-178.21700 -30.64210 40.10400)  5.6
# 3   POINT Z (144.63760 13.78760 148.41600)  5.0
# 4   POINT Z (-160.37210 54.97110 50.60800)  5.4
#
#                              place           time        type  \
# 0        Izu Islands, Japan region  1695331332556  earthquake
# 1       41 km WSW of Sola, Vanuatu  1695330709950  earthquake
# 2    Kermadec Islands, New Zealand  1695309632162  earthquake
# 3                             None  1695289702893  earthquake
# 4  41 km SSE of Sand Point, Alaska  1695258839537  earthquake
#
#                                      title
# 0        M 5.7 - Izu Islands, Japan region
# 1       M 6.1 - 41 km WSW of Sola, Vanuatu
# 2    M 5.6 - Kermadec Islands, New Zealand
# 3                                 M 5.0 -
# 4  M 5.4 - 41 km SSE of Sand Point, Alaska

# %%
gdf.shape
# Out:
# (16938, 6)

# %%
# Summary statistics
gdf.describe()
# Out:
#                 mag          time
# count  16938.000000  1.693800e+04
# mean       5.339767  1.539962e+12
# std        0.409267  9.071723e+10
# min        5.000000  1.379945e+12
# 25%        5.100000  1.462441e+12
# 50%        5.200000  1.540908e+12
# 75%        5.500000  1.618661e+12
# max        8.300000  1.695331e+12

# %%
# Data types
gdf.dtypes
# Out:
# geometry    geometry
# mag          float64
# place         object
# time           int64
# type          object
# title         object
# dtype: object

# %%
# Missing values
gdf.isnull().sum()
# Out:
# geometry      0
# mag           0
# place       206
# time          0
# type          0
# title         0
# dtype: int64

# %%
# Unique values for a particular column, for instance 'type' (like earthquake, explosion etc.)
gdf['type'].unique()
# Out:
# array(['earthquake', 'volcanic eruption', 'nuclear explosion'],
#       dtype=object)

# %%
type_counts = gdf['type'].value_counts()
print(type_counts)
# Out:
# type
# earthquake           16880
# volcanic eruption       55
# nuclear explosion        3
# Name: count, dtype: int64

# %%
# Save to Excel if needed.
#gdf.head().to_excel('Header of the dataset.xlsx')
#gdf.describe().to_excel('Describtion of the dataset.xlsx')
#gdf.dtypes.to_excel('Types of features of the dataset.xlsx')
#gdf.isnull().sum().to_excel('Null values of the dataset.xlsx')

# %% [markdown]
# # Magnitude VS Depth analysis

# %%
# Distribution of magnitudes
gdf['mag'].hist(bins=35, edgecolor='black')
plt.xlabel('Magnitude')
plt.ylabel('Frequency')
plt.title('Distribution of Earthquake Magnitudes')
plt.show()

# %%
# Categorizing earthquakes based on magnitude
categories = ["Moderate", "Strong", "Major", "Great"]
bins = [5.0, 6.0, 7.0, 8.0, np.inf]
gdf['magnitude_category'] = pd.cut(gdf['mag'], bins=bins, labels=categories, right=False)

# Determining the frequency for each category
frequency = gdf['magnitude_category'].value_counts().sort_index()

print(frequency)

# Optional: Plotting the frequencies
plt.figure(figsize=(10, 6))
frequency.plot(kind='bar', edgecolor='black')
plt.title('Frequency of Earthquakes in Different Richter Scale Categories')
plt.xlabel('Magnitude Category')
plt.ylabel('Number of Earthquakes')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()
# Out:
# /home/codespace/.python/current/lib/python3.10/site-packages/geopandas/geodataframe.py:1543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# magnitude_category
# Moderate    15555
# Strong       1241
# Major         134
# Great           8
# Name: count, dtype: int64

# %%
# Categorizing earthquakes based on magnitude
categories = ["Moderate", "Strong", "Major", "Great"]
bins = [5.0, 6.0, 7.0, 8.0, np.inf]
gdf['magnitude_category'] = pd.cut(gdf['mag'], bins=bins, labels=categories, right=False)

# Determining the frequency for each category
frequency = gdf['magnitude_category'].value_counts().sort_index()

# Calculating the percentage for each category
total_earthquakes = len(gdf)
percentage = (frequency / total_earthquakes) * 100

# Displaying the frequency and percentage
for cat, freq, perc in zip(categories, frequency, percentage):
    print(f"{cat}: {freq} earthquakes ({perc:.2f}%)")

# Optional: Plotting the frequencies with percentage annotations
plt.figure(figsize=(10, 6))
ax = frequency.plot(kind='bar', edgecolor='black')
plt.title('Frequency of Earthquakes in Different Richter Scale Categories')
plt.xlabel('Magnitude Category')
plt.ylabel('Number of Earthquakes')
plt.xticks(rotation=45)
plt.grid(axis='y')

# Annotating the bars with percentages
for p in ax.patches:
    ax.annotate(f"{p.get_height()} ({p.get_height() / total_earthquakes * 100:.2f}%)", 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', 
                xytext=(0, 10), 
                textcoords='offset points')

plt.tight_layout()
plt.show()
# Out:
# /home/codespace/.python/current/lib/python3.10/site-packages/geopandas/geodataframe.py:1543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# Moderate: 15555 earthquakes (91.83%)
# Strong: 1241 earthquakes (7.33%)
# Major: 134 earthquakes (0.79%)
# Great: 8 earthquakes (0.05%)

# %%
# Extract depth from the geometry column
gdf['depth'] = gdf['geometry'].apply(lambda geom: geom.z)

# 1. Histogram
plt.figure(figsize=(10, 6))
gdf['depth'].hist(bins=50, edgecolor='black')
plt.title('Distribution of Earthquake Depths')
plt.xlabel('Depth (km)')
plt.ylabel('Number of Earthquakes')
plt.show()
# Out:
# /home/codespace/.python/current/lib/python3.10/site-packages/geopandas/geodataframe.py:1543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
# 2. Categorization
shallow = gdf[gdf['depth'] <= 70]
intermediate = gdf[(gdf['depth'] > 70) & (gdf['depth'] <= 300)]
deep = gdf[gdf['depth'] > 300]

total_earthquakes = len(gdf)

shallow_percentage = (len(shallow) / total_earthquakes) * 100
intermediate_percentage = (len(intermediate) / total_earthquakes) * 100
deep_percentage = (len(deep) / total_earthquakes) * 100

# Categories and Frequencies
categories = ['Shallow', 'Intermediate', 'Deep']
frequency = [len(shallow), len(intermediate), len(deep)]
percentage = [(f/total_earthquakes)*100 for f in frequency]

# Displaying the frequency and percentage
for cat, freq, perc in zip(categories, frequency, percentage):
    print(f"{cat}: {freq} earthquakes ({perc:.2f}%)")

# Plotting the frequencies with percentage annotations
plt.figure(figsize=(10, 6))
ax = plt.bar(categories, frequency, edgecolor='black')
plt.title('Distribution of Earthquakes by Depth')
plt.xlabel('Depth Category')
plt.ylabel('Number of Earthquakes')
plt.xticks(rotation=45)
plt.grid(axis='y')

# Annotating the bars with percentages
for p in ax:
    height = p.get_height()
    plt.annotate(f"{height} ({height / total_earthquakes * 100:.2f}%)", 
                (p.get_x() + p.get_width() / 2., height), 
                ha='center', va='center', 
                xytext=(0, 10), 
                textcoords='offset points')

plt.tight_layout()
plt.show()
# Out:
# Shallow: 14055 earthquakes (82.98%)
# Intermediate: 2233 earthquakes (13.18%)
# Deep: 650 earthquakes (3.84%)

# %%
# Create a joint plot
sns.jointplot(data=gdf, x='depth', y='mag', kind='scatter', height=8, marginal_kws=dict(bins=50, fill=False))

plt.suptitle('Magnitude by Depth with Depth Distribution', y=1.02)
plt.show()

# %%
corr = gdf['depth'].corr(gdf['mag'])
print(f'Correlation between depth and magnitude: {corr:.2f}')
# Out:
# Correlation between depth and magnitude: 0.10

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=gdf, x='depth', y='mag', hue='mag', palette='viridis', edgecolor=None, alpha=0.7)
plt.title('Magnitude by Depth')
plt.show()

# %% [markdown]
# # Map distributions

# %%
# Adjust the longitude values in the GeoDataFrame
gdf['geometry_map'] = gdf['geometry'].apply(lambda geom: geom if geom.x >= 0 else shapely.geometry.Point(geom.x + 360, geom.y))

# Create a new figure with a specific size
plt.figure(figsize=(15, 10))

# Create a basemap with 'mill' projection (cylindrical)
m = Basemap(projection='mill',llcrnrlat=-60,urcrnrlat=90,\
            llcrnrlon=0,urcrnrlon=360,resolution='c')

# Draw coastlines and countries
m.drawcoastlines()
m.drawcountries()

# Extract latitude and longitude from the GeoDataFrame
latitude = gdf['geometry_map'].y.values
longitude = gdf['geometry_map'].x.values

# Convert latitude and longitude to x and y coordinates
x, y = m(longitude, latitude)

# Plot the heatmap using hexbin
m.hexbin(x, y, gridsize=500, bins='log', cmap='inferno')

# Add a colorbar on the right side
cb = plt.colorbar(label='Number of Earthquakes')
cb.set_label('Log(Number of Earthquakes)')

# Add a title
plt.title("Earthquake Activities (Magnitude > 5.0) from 2013-09-22 to 2023-09-22")

# Show the plot
plt.show()
# Out:
# /home/codespace/.python/current/lib/python3.10/site-packages/geopandas/geodataframe.py:1543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
# Create a new figure with a specific size
plt.figure(figsize=(15, 10))

# Create a basemap with 'mill' projection (cylindrical)
m = Basemap(projection='mill',llcrnrlat=-60,urcrnrlat=90,\
            llcrnrlon=0,urcrnrlon=360,resolution='c')

# Extract latitude and longitude from the GeoDataFrame
latitude = gdf['geometry_map'].y.values
longitude = gdf['geometry_map'].x.values

# Convert latitude and longitude to x and y coordinates
x, y = m(longitude, latitude)

# Plot the heatmap using hexbin
m.hexbin(x, y, gridsize=500, bins='log', cmap='inferno')

# Add a colorbar on the right side
cb = plt.colorbar(label='Number of Earthquakes')
cb.set_label('Log(Number of Earthquakes)')

# Add a title
plt.title("Earthquake Activities (Magnitude > 5.0) from 2013-09-22 to 2023-09-22")

# Show the plot
plt.show()

# %%
# Binning Earthquake Magnitudes
bins = [5, 6, 7, 8, 9, 10]
labels = ['5-6', '6-7', '7-8', '8-9', '9-10']
gdf['magnitude_bin'] = pd.cut(gdf['mag'], bins=bins, labels=labels, right=False)

# Create a new figure with a specific size
plt.figure(figsize=(15, 10))

# Create a basemap with 'mill' projection (cylindrical)
m = Basemap(projection='mill',llcrnrlat=-60,urcrnrlat=90,\
            llcrnrlon=0,urcrnrlon=360,resolution='c')

# Draw coastlines and countries
m.drawcoastlines()
m.drawcountries()

# Extract latitude and longitude from the GeoDataFrame
latitude = gdf['geometry_map'].y.values
longitude = gdf['geometry_map'].x.values

# Plot earthquakes, color-coded by magnitude bin
colors = {'5-6': 'blue', '6-7': 'green', '7-8': 'yellow', '8-9': 'orange', '9-10': 'red'}
for label, color in colors.items():
    mask = gdf['magnitude_bin'] == label
    x, y = m(longitude[mask], latitude[mask])
    m.scatter(x, y, color=color, label=label, s=50, alpha=0.5)

# Add a legend
plt.legend(title="Magnitude")

# Add a title
plt.title("Seismic Zones: Earthquake Magnitudes from 2013-09-22 to 2023-09-22")

# Show the plot
plt.show()
# Out:
# /home/codespace/.python/current/lib/python3.10/site-packages/geopandas/geodataframe.py:1543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
# Create a new figure with a specific size
plt.figure(figsize=(15, 10))

# Create a basemap with 'mill' projection (cylindrical)
m = Basemap(projection='mill',llcrnrlat=-60,urcrnrlat=90,\
            llcrnrlon=0,urcrnrlon=360,resolution='c')

# Draw coastlines and countries
m.drawcoastlines()
m.drawcountries()

# Extract latitude and longitude from the GeoDataFrame
latitude = gdf['geometry_map'].y.values
longitude = gdf['geometry_map'].x.values

# Plot earthquakes, color-coded by magnitude bin
colors = {'5-6': 'blue', '6-7': 'green', '7-8': 'yellow', '8-9': 'orange', '9-10': 'red'}
sizes = {'5-6': 50, '6-7': 50, '7-8': 50, '8-9': 200, '9-10': 300}
alphas = {'5-6': 0.5, '6-7': 0.5, '7-8': 0.5, '8-9': 0.8, '9-10': 1.0}

for label, color in colors.items():
    mask = gdf['magnitude_bin'] == label
    x, y = m(longitude[mask], latitude[mask])
    m.scatter(x, y, color=color, label=label, s=sizes[label], alpha=alphas[label])

# Add a legend
plt.legend(title="Magnitude")

# Add a title
plt.title("Seismic Zones: Earthquake Magnitudes from 2013-09-22 to 2023-09-22")

# Show the plot
plt.show()

# %%
# Create a new figure with a specific size
plt.figure(figsize=(15, 10))

# Adjust the boundaries to focus on the Ring of Fire region
m = Basemap(projection='mill',llcrnrlat=-50,urcrnrlat=70,\
            llcrnrlon=80,urcrnrlon=290,resolution='l')  # Use 'l' resolution for better detail

# Draw coastlines and countries
m.drawcoastlines()
m.drawcountries()

# Extract latitude and longitude from the GeoDataFrame
latitude = gdf['geometry_map'].y.values
longitude = gdf['geometry_map'].x.values

# Plot earthquakes, color-coded by magnitude bin
colors = {'5-6': 'blue', '6-7': 'green', '7-8': 'yellow', '8-9': 'orange', '9-10': 'red'}
sizes = {'5-6': 50, '6-7': 50, '7-8': 50, '8-9': 200, '9-10': 300}
alphas = {'5-6': 0.5, '6-7': 0.5, '7-8': 0.5, '8-9': 0.8, '9-10': 1.0}

for label, color in colors.items():
    mask = gdf['magnitude_bin'] == label
    x, y = m(longitude[mask], latitude[mask])
    m.scatter(x, y, color=color, label=label, s=sizes[label], alpha=alphas[label])

# Add a legend
plt.legend(title="Magnitude")

# Add a title
plt.title("Seismic Zones in the Ring of Fire: Earthquake Magnitudes from 2013-09-22 to 2023-09-22")

# Show the plot
plt.show()

# %%
# Sort the GeoDataFrame by magnitude and select the top 10
top_10_earthquakes = gdf.sort_values(by='mag', ascending=False).head(10)

# Create a new figure with a specific size
plt.figure(figsize=(15, 10))

# Create a basemap with global view
m = Basemap(projection='mill',llcrnrlat=-60,urcrnrlat=90,\
            llcrnrlon=0,urcrnrlon=360,resolution='l')

# Draw coastlines and countries
m.drawcoastlines()
m.drawcountries()

# Extract latitude and longitude from the top 10 earthquakes
latitude = top_10_earthquakes['geometry_map'].y.values
longitude = top_10_earthquakes['geometry_map'].x.values

# Plot the top 10 earthquakes, using size to represent magnitude
x, y = m(longitude, latitude)
m.scatter(x, y, color='red', s=top_10_earthquakes['mag']**3, alpha=0.8, label='Top 10 Earthquakes')

# Annotate the earthquakes with their magnitude
for idx, (i, row) in enumerate(top_10_earthquakes.iterrows()):
    plt.text(x[idx], y[idx], f"{row['mag']:.1f}", fontsize=12, ha='center', color='white')


# Add a title
plt.title("Top 10 Highest Magnitude Earthquakes from 2013-09-22 to 2023-09-22")

# Show the plot
plt.show()

# %%
# Convert the 'time' column from milliseconds to datetime format
gdf['time'] = pd.to_datetime(gdf['time'], unit='ms')
# Out:
# /home/codespace/.python/current/lib/python3.10/site-packages/geopandas/geodataframe.py:1543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
# Sort the GeoDataFrame by magnitude in descending order and select the top 10
top_10_earthquakes = gdf.sort_values(by='mag', ascending=False).head(10)

# Display the relevant columns for the top 10 highest earthquakes
top_10_earthquakes[['mag', 'depth', 'time', 'place']]
# Out:
#        mag   depth                    time  \
# 13694  8.3   22.44 2015-09-16 22:54:32.860
# 16130  8.2   25.00 2014-04-01 23:46:47.260
# 10479  8.2   47.39 2017-09-08 04:49:19.180
# 8953   8.2  600.00 2018-08-19 00:19:40.670
# 3796   8.2   35.00 2021-07-29 06:15:49.188
# 4639   8.1   28.93 2021-03-04 19:28:33.178
# 3708   8.1   22.79 2021-08-12 18:35:17.231
# 7519   8.0  122.57 2019-05-26 07:41:15.073
# 11407  7.9  135.00 2017-01-22 04:30:22.960
# 9886   7.9   14.06 2018-01-23 09:31:40.890
#
#                                         place
# 13694               48 km W of Illapel, Chile
# 16130              93 km NW of Iquique, Chile
# 10479       near the coast of Chiapas, Mexico
# 8953                 267 km E of Levuka, Fiji
# 3796                         Alaska Peninsula
# 4639            Kermadec Islands, New Zealand
# 3708            South Sandwich Islands region
# 7519                78 km NE of Navarro, Peru
# 11407  35 km WNW of Panguna, Papua New Guinea
# ...

# %% [markdown]
# # Temporal Analysis

# %%
# Set the 'time' column as the dataframe's index (optional but can be helpful)
gdf.set_index('time', inplace=True)

# %%
# Check the first few rows to confirm the change
gdf.head()
# Out:
#                                                         geometry  mag  \
# time
# 2023-09-21 21:22:12.556    POINT Z (141.83280 30.95780 12.73400)  5.7
# 2023-09-21 21:11:49.950  POINT Z (167.18980 -14.00390 188.41900)  6.1
# 2023-09-21 15:20:32.162  POINT Z (-178.21700 -30.64210 40.10400)  5.6
# 2023-09-21 09:48:22.893   POINT Z (144.63760 13.78760 148.41600)  5.0
# 2023-09-21 01:13:59.537   POINT Z (-160.37210 54.97110 50.60800)  5.4
#
#                                                    place        type  \
# time
# 2023-09-21 21:22:12.556        Izu Islands, Japan region  earthquake
# 2023-09-21 21:11:49.950       41 km WSW of Sola, Vanuatu  earthquake
# 2023-09-21 15:20:32.162    Kermadec Islands, New Zealand  earthquake
# 2023-09-21 09:48:22.893                             None  earthquake
# 2023-09-21 01:13:59.537  41 km SSE of Sand Point, Alaska  earthquake
#
#                                                            title  \
# time
# ...

# %%
# Resample the data to get earthquake counts for each month
monthly_counts = gdf.resample('M').size()

# Plot the data
plt.figure(figsize=(15, 6))
monthly_counts.plot(lw=2)
plt.title('Monthly Earthquake Counts')
plt.xlabel('Time')
plt.ylabel('Number of Earthquakes')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Create a new column for the month
gdf['month'] = gdf.index.month

# Bin the magnitudes
bins = [5, 6, 7, 8, 9, 10]
labels = ['5-6', '6-7', '7-8', '8-9', '9-10']
gdf['magnitude_bin'] = pd.cut(gdf['mag'], bins=bins, labels=labels, right=False)

# Create a pivot table for the heatmap
heatmap_data = gdf.pivot_table(index='magnitude_bin', columns='month', aggfunc='size', fill_value=0)

# Month names for labeling the x-axis
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# Plotting the heatmap with adjusted annotations
plt.figure(figsize=(12, 7))
sns.heatmap(heatmap_data, annot=True, cmap='YlGnBu', linewidths=.5, xticklabels=months, fmt='d', cbar_kws={'label': 'Earthquake Count'})
plt.title('Earthquake Frequency by Month and Magnitude')
plt.xlabel('Month')
plt.ylabel('Magnitude')
plt.tight_layout()
plt.show()
# Out:
# /home/codespace/.python/current/lib/python3.10/site-packages/geopandas/geodataframe.py:1543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /home/codespace/.python/current/lib/python3.10/site-packages/geopandas/geodataframe.py:1543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
# Calculate the earthquake counts by magnitude bin for each month
monthly_counts_by_bin = gdf.groupby(['month', 'magnitude_bin']).size().unstack(fill_value=0)

# Calculate the monthly average magnitude
monthly_avg_magnitude = gdf.groupby('month')['mag'].mean()

# Set up the plot
fig, ax1 = plt.subplots(figsize=(15, 7))

# Plot the bars (monthly counts by magnitude bin)
monthly_counts_by_bin.plot(kind='bar', stacked=True, ax=ax1, colormap='viridis')
ax1.set_ylabel('Earthquake Count')
ax1.set_xlabel('Month')
ax1.set_title('Monthly Earthquake Frequency and Average Magnitude')
ax1.set_xticklabels(months, rotation=45)

# Set up the secondary Y-axis for the line plot
ax2 = ax1.twinx()
ax2.plot(monthly_avg_magnitude.index, monthly_avg_magnitude.values, color='red', marker='o', label='Average Magnitude')
ax2.set_ylabel('Average Magnitude', color='red')
ax2.tick_params(axis='y', labelcolor='red')
ax2.legend(loc='upper right')

plt.tight_layout()
plt.show()
